# %% [markdown]
# <a href="https://colab.research.google.com/github/farrukh61/CCPP-Power-Output-Prediction/blob/main/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
import seaborn as sns
from google.colab import drive

drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# DATA
df = pd.read_csv('/drive/MyDrive/ml project/ccpp_data.csv')
x = df.drop('PE',axis=1)
y = df.PE

# %%
df.head()
# Out:
#        AT       V        AP      RH       PE
# 0 14.9600 41.7600 1024.0700 73.1700 463.2600
# 1 25.1800 62.9600 1020.0400 59.0800 444.3700
# 2  5.1100 39.4000 1012.1600 92.1400 488.5600
# 3 20.8600 57.3200 1010.2400 76.6400 446.4800
# 4 10.8200 37.5000 1009.2300 96.6200 473.9000

# %%
# # setting the dimensions of the plot
# fig, ax = plt.subplots(figsize=(4, 5))
# sns.pairplot(data=df, y_vars=['PE'], x_vars=['AT', 'V', 'AP', 'RH'])
# plt.show()

# %%
sns.pairplot(data=df, kind='reg', diag_kind='kde',x_vars=['AT','V','AP','RH'],y_vars=['PE'],palette='Reds', height=2.5, plot_kws={"line_kws": {"color": "black",}})
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, cmap = 'coolwarm', annot= True,linewidths=.05);
